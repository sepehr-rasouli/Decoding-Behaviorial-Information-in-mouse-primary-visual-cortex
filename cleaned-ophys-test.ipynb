# %%
import pandas as pd
experiments_table = pd.read_csv('cleaned-ophyexp_v1.csv')
# experiment_df.to_csv('cleaned-ophyexp_v1.csv')
# experiments_table

# for mouse_id = 448900
# ophys_experiment_id = 873968820
# ophys_experiment_id = 877018118
# ophys_experiment_id = 878358326
####################

# drop the experiments we already did
# experiments_table=experiments_table[~experiments_table['ophys_experiment_id'].isin([873968820, 877018118, 878358326])]
experiments_table.head()
# Out:
#    ophys_experiment_id equipment_name  \
# 0            792815735        CAM2P.4
# 1            795073741        CAM2P.4
# 2            795953296        CAM2P.4
# 3            796308505        CAM2P.4
# 4            826587940        CAM2P.4
#
#                                    full_genotype  mouse_id  \
# 0  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    412036
# 1  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    412036
# 2  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    412036
# 3  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    412036
# 4  Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    429952
#
#                 reporter_line       driver_line sex  age_in_days  \
# 0  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F          148
# 1  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F          151
# 2  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F          152
# 3  Ai148(TIT2L-GC6f-ICL-tTA2)  ['Vip-IRES-Cre']   F          154
# ...

# %%
# experiments_table.loc[396:,:]

# %%
import dtale
dtale.show(experiments_table)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-7N0SJFV6:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
