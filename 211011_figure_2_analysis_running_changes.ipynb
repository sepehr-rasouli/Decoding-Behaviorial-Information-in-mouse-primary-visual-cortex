# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_context("notebook", font_scale=1.5, rc={"lines.markeredgewidth": 2})
from pathlib import Path
# Out:
# C:\Users\sepeh\.conda\envs\allen-sdk\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\sepeh\.conda\envs\allen-sdk\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\sepeh\.conda\envs\allen-sdk\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\sepeh\.conda\envs\allen-sdk\lib\site-packages\numpy\.libs\libopenblas.xwydx2ikjw2nmtwsfyngfuwkqu3lytcz.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
# from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorOphysProjectCache
import allensdk.brain_observatory.behavior.behavior_project_cache as bpc
from visual_behavior.data_access import loading as loading
# Out:
# C:\Users\sepeh\AppData\Roaming\Python\Python37\site-packages\visual_behavior\data_access\from_lims.py:37: UserWarning: failed to set up LIMS/mtrain credentials
# 'LIMS_DBNAME'
#
#          internal AIBS users should set up environment variables         appropriately
# functions requiring database access will fail
#   warnings.warn(warn_string)
# C:\Users\sepeh\AppData\Roaming\Python\Python37\site-packages\visual_behavior\data_access\loading.py:53: UserWarning: failed to set up LIMS/mtrain credentials
# 'LIMS_DBNAME'
#
# internal AIBS users should set up environment variables appropriately
# functions requiring database access will fail
#   warnings.warn(warn_string)

# %%
import visual_behavior.data_access.utilities as utilities
import visual_behavior.visualization.ophys.platform_paper_figures as ppf

# %% [markdown]
# ### load experiments_table from cache

# %%
# cache_dir = loading.get_platform_analysis_cache_dir()
my_cache_dir = Path("G:/allensdk")
cache = bpc.VisualBehaviorOphysProjectCache.from_s3_cache(cache_dir=my_cache_dir)
# print(cache_dir)

# %%
experiments_table = cache.get_ophys_experiment_table()
# experiments_table
print(len(experiments_table))
# Out:
# 1941

# %% [markdown]
# ### limit to containers with all 3 experience levels

# %%
experiments_table = utilities.limit_to_containers_with_all_experience_levels(
    experiments_table
)

# %%
print(len(experiments_table))
# Out:
# 1415

# %% [markdown]
# #### add useful columns

# %%
experiments_table = utilities.add_cell_type_column(experiments_table)
experiments_table = utilities.add_experience_exposure_column(experiments_table)
# experiments_table = utilities.add_binned_depth_column(experiments_table)
# Out:
# C:\Users\sepeh\.conda\envs\allen-sdk\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %% [markdown]
# ### get useful info

# %%
experience_level = np.sort(experiments_table.experience_level.unique())
print(experience_level)
# Out:
# ['Familiar' 'Novel 1' 'Novel >1']

# %%
experiments_table.cre_line.nunique()
# Out:
# 3

# %%
pd.set_option("display.max_columns", None)
experiments_table
# Out:
#                     equipment_name  \
# ophys_experiment_id
# 951980486                   MESO.1
# 951980473                   MESO.1
# 951980481                   MESO.1
# 951980471                   MESO.1
# 951980475                   MESO.1
# ...                            ...
# 947716576                  CAM2P.4
# 948507789                  CAM2P.4
# 950833329                  CAM2P.4
# 953443028                  CAM2P.4
# 958435448                  CAM2P.4
#
#                                                      full_genotype  mouse_id  \
# ophys_experiment_id
# 951980486            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980473            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980481            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980471            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980475            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# ...                                                            ...       ...
# 947716576            Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    468866
# 948507789            Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    468866
# 950833329            Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    468866
# 953443028            Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    468866
# 958435448            Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    468866
#
#                                   reporter_line     driver_line sex  \
# ophys_experiment_id
# 951980486            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# 951980473            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# 951980481            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# 951980471            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# 951980475            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# ...                                         ...             ...  ..
# 947716576            Ai148(TIT2L-GC6f-ICL-tTA2)  [Vip-IRES-Cre]   F
# 948507789            Ai148(TIT2L-GC6f-ICL-tTA2)  [Vip-IRES-Cre]   F
# 950833329            Ai148(TIT2L-GC6f-ICL-tTA2)  [Vip-IRES-Cre]   F
# 953443028            Ai148(TIT2L-GC6f-ICL-tTA2)  [Vip-IRES-Cre]   F
# 958435448            Ai148(TIT2L-GC6f-ICL-tTA2)  [Vip-IRES-Cre]   F
#
#                      age_in_days      cre_line indicator  session_number  \
# ophys_experiment_id
# 951980486                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# 951980473                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# 951980481                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# 951980471                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# 951980475                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# ...                          ...           ...       ...             ...
# 947716576                  152.0  Vip-IRES-Cre   GCaMP6f             3.0
# 948507789                  153.0  Vip-IRES-Cre   GCaMP6f             3.0
# 950833329                  155.0  Vip-IRES-Cre   GCaMP6f             4.0
# 953443028                  159.0  Vip-IRES-Cre   GCaMP6f             6.0
# 958435448                  160.0  Vip-IRES-Cre   GCaMP6f             5.0
#
#                      prior_exposures_to_session_type  \
# ophys_experiment_id
# 951980486                                        0.0
# 951980473                                        0.0
# 951980481                                        0.0
# 951980471                                        0.0
# 951980475                                        0.0
# ...                                              ...
# 947716576                                        1.0
# 948507789                                        2.0
# 950833329                                        0.0
# 953443028                                        0.0
# 958435448                                        0.0
#
#                      prior_exposures_to_image_set  \
# ophys_experiment_id
# 951980486                                    65.0
# 951980473                                    65.0
# 951980481                                    65.0
# 951980471                                    65.0
# 951980475                                    65.0
# ...                                           ...
# 947716576                                    21.0
# 948507789                                    22.0
# 950833329                                     0.0
# 953443028                                     1.0
# 958435448                                     2.0
#
#                      prior_exposures_to_omissions  ophys_session_id  \
# ophys_experiment_id
# 951980486                                     0.0         951410079
# 951980473                                     0.0         951410079
# 951980481                                     0.0         951410079
# 951980471                                     0.0         951410079
# 951980475                                     0.0         951410079
# ...                                           ...               ...
# 947716576                                     7.0         946951902
# 948507789                                     8.0         948090163
# 950833329                                    10.0         949209988
# 953443028                                    11.0         952434025
# 958435448                                    12.0         954958035
#
#                      behavior_session_id  ophys_container_id  \
# ophys_experiment_id
# 951980486                      951520319          1018028360
# 951980473                      951520319          1018028345
# 951980481                      951520319          1018028357
# 951980471                      951520319          1018028342
# 951980475                      951520319          1018028339
# ...                                  ...                 ...
# 947716576                      947311015           929913236
# 948507789                      948206919           929913236
# 950833329                      950157787           929913236
# 953443028                      952746230           929913236
# 958435448                      954120560           929913236
#
#                                  project_code  imaging_depth  \
# ophys_experiment_id
# 951980486            VisualBehaviorMultiscope            300
# 951980473            VisualBehaviorMultiscope            225
# 951980481            VisualBehaviorMultiscope            225
# 951980471            VisualBehaviorMultiscope            150
# 951980475            VisualBehaviorMultiscope             75
# ...                                       ...            ...
# 947716576                      VisualBehavior            175
# 948507789                      VisualBehavior            175
# 950833329                      VisualBehavior            175
# 953443028                      VisualBehavior            175
# 958435448                      VisualBehavior            175
#
#                     targeted_structure         date_of_acquisition  \
# ophys_experiment_id
# 951980486                         VISl  2019-09-20 09:45:29.897856
# 951980473                         VISp  2019-09-20 09:45:29.897856
# 951980481                         VISl  2019-09-20 09:45:29.897856
# 951980471                         VISp  2019-09-20 09:45:29.897856
# 951980475                         VISp  2019-09-20 09:45:29.897856
# ...                                ...                         ...
# 947716576                         VISp  2019-09-16 16:46:16.000000
# 948507789                         VISp  2019-09-17 17:39:10.000000
# 950833329                         VISp  2019-09-19 15:34:06.000000
# 953443028                         VISp  2019-09-23 15:41:38.000000
# 958435448                         VISp  2019-09-25 16:00:00.000000
#
#                                  session_type experience_level  passive  \
# ophys_experiment_id
# 951980486                    OPHYS_1_images_A         Familiar    False
# 951980473                    OPHYS_1_images_A         Familiar    False
# 951980481                    OPHYS_1_images_A         Familiar    False
# 951980471                    OPHYS_1_images_A         Familiar    False
# 951980475                    OPHYS_1_images_A         Familiar    False
# ...                                       ...              ...      ...
# 947716576                    OPHYS_3_images_A         Familiar    False
# 948507789                    OPHYS_3_images_A         Familiar    False
# 950833329                    OPHYS_4_images_B          Novel 1    False
# 953443028                    OPHYS_6_images_B         Novel >1    False
# 958435448            OPHYS_5_images_B_passive         Novel >1     True
#
#                     image_set     file_id       cell_type experience_exposure  \
# ophys_experiment_id
# 951980486                   A  1085400869  Sst Inhibitory          Familiar 0
# 951980473                   A  1085400919  Sst Inhibitory          Familiar 0
# 951980481                   A  1085400972  Sst Inhibitory          Familiar 0
# 951980471                   A  1085394308  Sst Inhibitory          Familiar 0
# 951980475                   A  1085400920  Sst Inhibitory          Familiar 0
# ...                       ...         ...             ...                 ...
# 947716576                   A   947805783  Vip Inhibitory        Familiar > 3
# 948507789                   A   949405820  Vip Inhibitory        Familiar > 3
# 950833329                   B   951266634  Vip Inhibitory             Novel 0
# 953443028                   B   957237292  Vip Inhibitory             Novel 1
# 958435448                   B   958963900  Vip Inhibitory             Novel 2
#
#                     binned_depth
# ophys_experiment_id
# 951980486                   None
# 951980473                   None
# 951980481                   None
# 951980471                   None
# 951980475                   None
# ...                          ...
# 947716576                   None
# 948507789                   None
# 950833329                   None
# 953443028                   None
# 958435448                   None
#
# [1415 rows x 28 columns]

# %%
# experiments_table.experience_exposure

# %%
exposures = np.sort(experiments_table.experience_exposure.unique())
print(exposures)
# Out:
# ['Familiar 0' 'Familiar 1' 'Familiar 2' 'Familiar 3' 'Familiar > 3'
#  'Novel 0' 'Novel 1' 'Novel 2' 'Novel 3' 'Novel > 3']

# %%
cell_types = np.sort(experiments_table.cell_type.unique())
print(cell_types)
# Out:
# ['Excitatory' 'Sst Inhibitory' 'Vip Inhibitory']

# %% [markdown]
# ### get some experiment

# %%
# experiment_id = experiments_table.index.values[0]
experiment_id = 792815735
dataset = cache.get_behavior_ophys_experiment(experiment_id)

# %%
# new_exp_table = experiments_table[experiments_table.project_code=='VisualBehaviorMultiscope']
new_exp_table = experiments_table[experiments_table.mouse_id == 412036]

# %% [markdown]
# ### get multi_session_df

# %%
# %%time

# set various params
df_name = "trials_run_speed_df"
conditions = ["ophys_experiment_id", "stimulus_change"]
use_events = False
filter_events = False

# load multi_session_df
multi_session_df = loading.get_multi_session_df(
    my_cache_dir,
    df_name,
    conditions,
    new_exp_table,
    use_events=use_events,
    filter_events=filter_events,
)
print(len(multi_session_df.ophys_experiment_id.unique()))

# keep changes only
multi_session_df = multi_session_df[multi_session_df.stimulus_change == True]

# limit to platform paper dataset
multi_session_df = multi_session_df[
    multi_session_df.ophys_experiment_id.isin(experiments_table.index.values)
]
print(len(multi_session_df.ophys_experiment_id.unique()))

# merge with metadata
multi_session_df = multi_session_df.merge(experiments_table, on="ophys_experiment_id")
print(len(multi_session_df.ophys_experiment_id.unique()))

original_multi_session_df = multi_session_df.copy()
# Out:
# C:\Users\sepeh\AppData\Roaming\Python\Python37\site-packages\visual_behavior\data_access\loading.py:53: UserWarning: failed to set up LIMS/mtrain credentials
# 'LIMS_DBNAME'
#
# internal AIBS users should set up environment variables appropriately
# functions requiring database access will fail
#   warnings.warn(warn_string)
# no multi_session_df for VisualBehavior OPHYS_1_images_A
# no multi_session_df for VisualBehavior OPHYS_2_images_A_passive
# no multi_session_df for VisualBehavior OPHYS_3_images_A
# no multi_session_df for VisualBehavior OPHYS_4_images_B
# no multi_session_df for VisualBehavior OPHYS_5_images_B_passive
# no multi_session_df for VisualBehavior OPHYS_6_images_B
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\.conda\envs\allen-sdk\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ophys_experiment_id'

# %%
# multi_session_df = original_multi_session_df.copy()

# %%
# drop duplicates for sessions
multi_session_df = multi_session_df.drop_duplicates(subset=["ophys_session_id"])

# %%
# remove weird 7th epoch
# multi_session_df = multi_session_df[multi_session_df.epoch!=6]

# %%
# def merge_experience_epoch(row):
#     return row.experience_level+' epoch '+str(int(row.epoch))

# multi_session_df['experience_epoch'] = multi_session_df[['experience_level', 'epoch']].apply(axis=1, func=merge_experience_epoch)

# experience_epoch = np.sort(multi_session_df.experience_epoch.unique())

# %%
multi_session_df.keys()

# %%
df = multi_session_df.copy()
df = df[df.passive == False]
df["prior_exposures_to_image_set"] = [
    int(x) for x in df.prior_exposures_to_image_set.values
]

fig, ax = plt.subplots(1, 3, figsize=(15, 4))
for i, cell_type in enumerate(cell_types):
    ax[i] = sns.pointplot(
        data=df[(df.cell_type == cell_type) & (df.experience_level != "Familiar")],
        x="prior_exposures_to_image_set",
        y="mean_response",
        join=False,
        dodge=0.5,
        ax=ax[i],
    )
    ax[i].set_title(cell_type)
#     ax[i].legend(title='', fontsize='small', bbox_to_anchor=(1,1))
fig.tight_layout()

# %% [markdown]
# ### limit to containers with all exp levels, most recent familiar and second novel active

# %%
multi_session_df = utilities.limit_to_last_familiar_second_novel_active(
    multi_session_df
)
multi_session_df = utilities.limit_to_containers_with_all_experience_levels(
    multi_session_df
)

# %% [markdown]
# ### look at averages

# %%
import visual_behavior.visualization.utils as utils

# %%
palette = utils.get_experience_level_colors()
experience_levels = np.sort(multi_session_df.experience_level.unique())

fig, ax = plt.subplots()
ax = sns.pointplot(
    data=multi_session_df,
    x="cell_type",
    y="mean_response",
    hue="experience_level",
    hue_order=experience_levels,
    palette=palette,
    join=False,
    dodge=0.4,
    ax=ax,
)
ax.legend(loc="lower right", fontsize="small", title="")
ax.set_xlabel("")
ax.set_ylabel("mean running speed (cm/s)")
ax.set_ylim(ymin=0)

# %%
def add_experience_exposure_column(experiments_table):
    """
    adds a column to ophys_experiment_table that contains a string indicating the experience level and
    image set exposure number for Novel sessions, and experience level and prior omissions exposure for familiar sessions
    """
    experience_exposure_list = []
    for experiment_id in experiments_table.index.values:
        expt = experiments_table.loc[experiment_id]
        if "Familiar" in expt.experience_level:
            if expt.prior_exposures_to_omissions <= 3:
                exp = "Familiar " + str(int(expt.prior_exposures_to_omissions))
            else:
                exp = "Familiar > 3"
            experience_exposure_list.append(exp)
        elif "Novel" in expt.experience_level:
            if expt.prior_exposures_to_image_set <= 3:
                exp = "Novel " + str(int(expt.prior_exposures_to_image_set))
            else:
                exp = "Novel > 3"
            experience_exposure_list.append(exp)
    experiments_table.loc[:, "experience_exposure"] = experience_exposure_list
    return experiments_table
